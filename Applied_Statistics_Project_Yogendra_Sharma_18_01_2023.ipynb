# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #*Part A*

# %% [markdown]
# ###**Please refer the table below to answer below questions:**
# ###1.A. Refer above table and find the joint probability of the people who planned to purchase and actually placed an order:

# %%
500/2000
# Out:
# 0.25

# %% [markdown]
# ###1.B. Refer to the above table and find the joint probability of the people who planned to purchase and actually placed an order, given that people planned to purchase.

# %%
1500/2000
# Out:
# 0.75

# %% [markdown]
# ###**An electrical manufacturing company conducts quality checks at specified periods on the products it manufactures. Historically, the failure rate for the manufactured item is 5%. Suppose a random sample of 10 manufactured items is selected. Answer the following questions.**

# %% [markdown]
# ###2.A. Probability that none of the items are defective?

# %%
n=10;
p=0.05;
q=1-p;
q=1-0.05;
q=0.95;

# %% [markdown]
# P(x) = ⁿCₓpˣqⁿ⁻ˣ;

# %%
0.5987
# Out:
# 0.5987

# %% [markdown]
# ###2.B. Probability that exactly one of the items is defective?

# %% [markdown]
# P(1) =  ¹⁰C₁(0.05)¹(0.95)⁹

# %%
0.3151
# Out:
# 0.3151

# %% [markdown]
# ###2.C. Probability that two or fewer of the items are defective?

# %% [markdown]
# = P(0) + P(1) + P(2)
#
# P(2) =  ¹⁰C₂(0.05)²(0.95)⁸ = 0.07463

# %%
0.5987  + 0.3151 + 0.0746
# Out:
# 0.9884

# %% [markdown]
# ###2.D. Probability that three or more of the items are defective?

# %% [markdown]
# 1 (P(0) + P(1) + P(2) + P(3)

# %%
1 - 0.99891
# Out:
# 0.0010900000000000354

# %% [markdown]
# ###**3. A car salesman sells on an average 3 cars per week.**

# %% [markdown]
# ###3.A. What is Probability that in a given week he will sell some cars?

# %% [markdown]
# #### Probability that in a given week he will sell some cars P(X>0) = 1-P(X=0)
#
# #### Given an average of 3 cars per week, λ=3
#
# #### P(X=0)= ((e^-3)*3^0)/0!, e=2.71828 & 0!=1
# =((2.71828**-3)*(3**0))/1

# %%
0.04978716883618589
# Out:
# 0.04978716883618589

# %% [markdown]
# ###3.B. What is Probability that in a given week he will sell 2 or more but less than 5 cars?

# %%
0.61611
# Out:
# 0.61611

# %% [markdown]
# ###3.C. Plot the poisson distribution function for cumulative probability of cars sold per-week vs number of cars sold per week.

# %%
146.167
# Out:
# 146.167

# %% [markdown]
# ###**Explain 1 real life industry scenario (other than the ones mentioned above) where you can use the concepts learnt in this module of Applied Statistics to get data driven business solution.**

# %% [markdown]
# The government use statistical data to tale decisions regarding populations, health and education and subsequent budgeting on the same. It may research on data collected from several schools, hospital, ministry and other orgenization or NGO to check out if all the protocols are being followed or not.

# %% [markdown]
# #*Part B*

# %% [markdown]
# **Q1:Ans:**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Projects/DS+-+Part2+-+Basketball.csv')

# %%
df.head()
# Out:
#      Team  Tournament Score PlayedGames WonGames DrawnGames LostGames  \
# 0  Team 1          86  4385        2762     1647        552       563
# 1  Team 2          86  4262        2762     1581        573       608
# 2  Team 3          80  3442        2614     1241        598       775
# 3  Team 4          82  3386        2664     1187        616       861
# 4  Team 5          86  3368        2762     1209        633       920
#
#   BasketScored BasketGiven TournamentChampion Runner-up TeamLaunch  \
# 0         5947        3140                 33        23       1929
# 1         5900        3114                 25        25       1929
# 2         4534        3309                 10         8       1929
# 3         4398        3469                  6         6   1931to32
# 4         4631        3700                  8         7       1929
#
#    HighestPositionHeld
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# ...

# %%
df.shape
# Out:
# (61, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Team                 61 non-null     object
#  1   Tournament           61 non-null     int64
#  2   Score                61 non-null     object
#  3   PlayedGames          61 non-null     object
#  4   WonGames             61 non-null     object
#  5   DrawnGames           61 non-null     object
#  6   LostGames            61 non-null     object
#  7   BasketScored         61 non-null     object
#  8   BasketGiven          61 non-null     object
#  9   TournamentChampion   61 non-null     object
#  10  Runner-up            61 non-null     object
#  11  TeamLaunch           61 non-null     object
#  12  HighestPositionHeld  61 non-null     int64
# dtypes: int64(2), object(11)
# memory usage: 6.3+ KB

# %%
df.describe()
# Out:
#        Tournament  HighestPositionHeld
# count   61.000000            61.000000
# mean    24.000000             7.081967
# std     26.827225             5.276663
# min      1.000000             1.000000
# 25%      4.000000             3.000000
# 50%     12.000000             6.000000
# 75%     38.000000            10.000000
# max     86.000000            20.000000

# %%
df.describe(include='all').T
# Out:
#                     count unique     top freq      mean        std  min  25%  \
# Team                   61     61  Team 1    1       NaN        NaN  NaN  NaN
# Tournament           61.0    NaN     NaN  NaN      24.0  26.827225  1.0  4.0
# Score                  61     61    4385    1       NaN        NaN  NaN  NaN
# PlayedGames            61     53    2762    3       NaN        NaN  NaN  NaN
# WonGames               61     59       7    2       NaN        NaN  NaN  NaN
# DrawnGames             61     57      14    2       NaN        NaN  NaN  NaN
# LostGames              61     56      37    3       NaN        NaN  NaN  NaN
# BasketScored           61     60      70    2       NaN        NaN  NaN  NaN
# BasketGiven            61     61    3140    1       NaN        NaN  NaN  NaN
# TournamentChampion     61      8       -   52       NaN        NaN  NaN  NaN
# Runner-up              61     10       -   48       NaN        NaN  NaN  NaN
# ...

# %% [markdown]
# **Q2:Ans:**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fig = plt.figure(figsize = (35,5));
sns.histplot(data=df, x='Tournament',binwidth=50);
sns.histplot(data=df, x='Tournament',kde=True);
plt.title('Total:Turnament');
plt.xlabel('Number of Turnament');
plt.ylabel('Year of Turnament');

# %%
sns.boxplot(data=df, x='Tournament');

# %%
fig = plt.figure(figsize = (35,5));
sns.countplot(data=df, x='Tournament');
plt.title('Total:Turnament');
plt.xlabel('Number of Turnament');
plt.ylabel('Year of Turnament');

# %%
fig = plt.figure(figsize = (35,5));
sns.countplot(data=df, x='WonGames');
plt.title('Total Woned Match');
plt.xlabel('Number of Turnament');
plt.ylabel('Year of Turnament');

# %%
fig = plt.figure(figsize = (35,20));
sns.lineplot(data=df, x='HighestPositionHeld', y='WonGames');
plt.title('Total Woned Match');
plt.xlabel('Man of the Match');
plt.ylabel('Woned the Game');

# %% [markdown]
# # **Q3:Ans:**

# %% [markdown]
# We have all heard of the the 6Vs of data analysis which are Volume, Variety, Velocity, Veracity, Validity and Volatility.  In this way my suggestion is mention below:
#
# **Volume:**
# Big data implies enormous volumes of data. It used to be employees created data. Now that data is generated by machines, networks and human interaction on systems like social media the volume of data to be analyzed is massive. Yet, the volume of data is not as much the problem as other V’s like veracity.
# Variety:
# Variety refers to the many sources and types of data both structured and unstructured. We used to store data from sources like spreadsheets and databases. Now data comes in the form of emails, photos, videos, monitoring devices, PDFs, audio, etc. This variety of unstructured data creates problems for storage, mining and analyzing data. So, we should to make structured data first as per their data type than it stores it, your own location, then use it as per our requirements.
#
# **Velocity:**
# Big Data Velocity deals with the pace at which data flows in from sources like business processes, machines, networks and human interaction with things like social media sites, mobile devices, etc. The flow of data is massive and continuous. This real-time data can help researchers and businesses make valuable decisions that provide strategic competitive advantages and ROI if you are able to handle the velocity. My suggestion is that sampling data can help deal with issues like volume and velocity.
#
# **Veracity:**
# Big Data Veracity refers to the biases, noise and abnormality in data. Is the data that is being stored, and mined meaningful to the problem being analyzed. I feel veracity in data analysis is the biggest challenge when compares to things like volume and velocity. In scoping out your big data strategy you need to have your team and partners work to help keep your data clean and processes to keep ‘dirty data’ from accumulating in your systems.
#
# **Validity:**
# Like big data veracity is the issue of validity meaning is the data correct and accurate for the intended use. Clearly valid data is key to making the right decisions. I suggest that big data strategy and tools they offer to help with data veracity and validity.
#
# **Volatility:**
# Big data volatility refers to how long is data valid and how long should it be stored. In this world of real time data, you need to determine at what point is data no longer relevant to the current analysis. So, my suggestion some important Volatile data should be store, for some time to better analysis.

# %% [markdown]
# #*Part C*

# %% [markdown]
# # **Q1:Ans:**

# %%
data_2 = pd.read_csv('/content/drive/MyDrive/Projects/DS+-+Part3+-+CompanyX_EU.csv')

# %%
df2=data_2

# %% [markdown]
# **Q2-Data Exploration** A & B Answer:

# %%
df2.head()
# Out:
#            Startup             Product Funding             Event  \
# 0           2600Hz          2600hz.com     NaN   Disrupt SF 2013
# 1             3DLT            3dlt.com   $630K  Disrupt NYC 2013
# 2      3DPrinterOS     3dprinteros.com     NaN   Disrupt SF 2016
# 3       3Dprintler      3dprintler.com     $1M   Disrupt NY 2016
# 4  42 Technologies  42technologies.com     NaN  Disrupt NYC 2013
#
#             Result OperatingState
# 0       Contestant      Operating
# 1       Contestant         Closed
# 2       Contestant      Operating
# 3  Audience choice      Operating
# 4       Contestant      Operating

# %%
df2.describe()
# Out:
#        Startup     Product Funding      Event      Result OperatingState
# count      662         656     448        662         662            662
# unique     662         656     240         26           5              4
# top     2600Hz  2600hz.com     $1M  TC50 2008  Contestant      Operating
# freq         1           1      17         52         488            465

# %%
df2.describe(include='all').T
# Out:
#                count unique         top freq
# Startup          662    662      2600Hz    1
# Product          656    656  2600hz.com    1
# Funding          448    240         $1M   17
# Event            662     26   TC50 2008   52
# Result           662      5  Contestant  488
# OperatingState   662      4   Operating  465

# %% [markdown]
# **Data preprocessing & visualisation: **

# %%
from re import X
from pandas.core import apply
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1.loc[:,'Funds_in_million']=df1['Funding'].apply(lambda x:float(x[1:-1])/1000 if X[-1]=='K' else(float(x[1:-1])*1000 if x[-1]=='B') else float(x[1:-1])));
# Out:
#   File "<ipython-input-215-4b9dea9ca628>", line 1
#     df1.loc[:,'Funds_in_million']=df1['Funding'].apply(lambda x:float(x[1:-1])/1000 if X[-1]=='K' else(float(x[1:-1])*1000 if x[-1]=='B') else float(x[1:-1])));
#                                                                                                                                         ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(figsize = (30,50));
sns.stripplot(data=df, x='Funding', y='Startup');
plt.title('Total:Funding');
plt.xlabel('Number of Startups');
plt.ylabel('Year of funding');
